# %%
# !pip install langchain
# !pip install langchain-community
# !pip install langchain-openai
# Out:
# Requirement already satisfied: langchain in /opt/anaconda3/envs/av/lib/python3.12/site-packages (0.2.14)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (3.9.5)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.32 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (0.2.33)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (0.2.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (0.1.100)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (1.26.4)
# Requirement already satisfied: pydantic<3,>=1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (2.8.2)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.3)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.32->langchain) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from pydantic<3,>=1->langchain) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.5)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.32->langchain) (3.0.0)
# Requirement already satisfied: langchain-community in /opt/anaconda3/envs/av/lib/python3.12/site-packages (0.2.12)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (2.0.25)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (3.9.5)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: langchain<0.3.0,>=0.2.13 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (0.2.14)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.30 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (0.2.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (0.1.100)
# Requirement already satisfied: numpy<2.0.0,>=1.26.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (1.26.4)
# Requirement already satisfied: requests<3,>=2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (2.32.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-community) (8.2.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.2.0)
# Requirement already satisfied: attrs>=17.3.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (23.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.9.3)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.22.0)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain<0.3.0,>=0.2.13->langchain-community) (0.2.2)
# Requirement already satisfied: pydantic<3,>=1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain<0.3.0,>=0.2.13->langchain-community) (2.8.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.30->langchain-community) (4.11.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (0.27.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.0->langchain-community) (3.10.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2.2.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests<3,>=2->langchain-community) (2024.6.2)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from SQLAlchemy<3,>=1.4->langchain-community) (3.0.1)
# Requirement already satisfied: anyio in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (4.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.0.5)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (1.3.0)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.0->langchain-community) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.30->langchain-community) (3.0.0)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain-community) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from pydantic<3,>=1->langchain<0.3.0,>=0.2.13->langchain-community) (2.20.1)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: langchain-openai in /opt/anaconda3/envs/av/lib/python3.12/site-packages (0.1.22)
# Requirement already satisfied: langchain-core<0.3.0,>=0.2.33 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-openai) (0.2.33)
# Requirement already satisfied: openai<2.0.0,>=1.40.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-openai) (1.41.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: PyYAML>=5.3 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (6.0.1)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (1.33)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.75 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (0.1.100)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (23.2)
# Requirement already satisfied: pydantic<3,>=1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (2.8.2)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (8.2.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langchain-core<0.3.0,>=0.2.33->langchain-openai) (4.11.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.2.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.27.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (0.5.0)
# Requirement already satisfied: sniffio in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from openai<2.0.0,>=1.40.0->langchain-openai) (4.66.4)
# Requirement already satisfied: regex>=2022.1.18 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.10.3)
# Requirement already satisfied: requests>=2.26.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2.32.2)
# Requirement already satisfied: idna>=2.8 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.40.0->langchain-openai) (3.7)
# Requirement already satisfied: certifi in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (2024.6.2)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.40.0->langchain-openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.3.0,>=0.2.33->langchain-openai) (3.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from langsmith<0.2.0,>=0.1.75->langchain-core<0.3.0,>=0.2.33->langchain-openai) (3.10.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.33->langchain-openai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from pydantic<3,>=1->langchain-core<0.3.0,>=0.2.33->langchain-openai) (2.20.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.0.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/envs/av/lib/python3.12/site-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai) (2.2.1)

# %%
import os
import yaml
with open('chatgpt-api-credentials.yml') as file:
    openai_key = yaml.safe_load(file)
os.environ['OPENAI_API_KEY'] = openai_key['OPENAI-API-KEY']

# %%
from langchain_core.prompts import PromptTemplate
from langchain_openai import ChatOpenAI

# %%
paper_abstract = f"""
The widespread use of ChatGPT and other emerging technology powered by generative
artificial intelligence (AI) has drawn much attention to potential ethical issues, especially in
high-stakes applications such as healthcare.1–3 However, less clear is how to resolve such
issues beyond following guidelines and regulations that are still under discussion and
development. On the other hand, other types of generative AI have been used to synthesize
images and other types of data for research and practical purposes, which have resolved some
ethical issues and exposed other ethical issues,4,5 but such technology is less often the focus
of ongoing ethical discussions. Here we highlight gaps in current ethical discussions of
generative AI via a systematic scoping review of relevant existing research in healthcare, and
reduce the gaps by proposing an ethics checklist for comprehensive assessment and
transparent documentation of ethical discussions in generative AI development. While the
checklist can be readily integrated into the current peer review and publication system to
enhance generative AI research, it may also be used in broader settings to disclose ethics related considerations in generative AI-powered products (or real-life applications of such
products) to help users establish reasonable trust in their capabilities.

Current ethical discussions on generative AI in healthcare
We conducted a systematic scoping review to analyse current ethical discussions on
generative AI in healthcare. Our search in four major academic research databases for
relevant publications from January 2013 to July 2023 yielded 2859 articles (see Methods for
detailed search strategy and Supplementary Figure S1 for the PRISMA flow diagram), of
which 193 articles were included for analysis based on application data modality (text, image,
or structured data), ethical issues discussed, generative AI involved, and whether generative
AI causes or offers technical solutions for issues raised.

Generative AI for text data-based healthcare
Forty-one of the 193 articles discussed ethical considerations pertaining to generative AI
applications for text data, with 20 articles describing methodological developments or
applications of generative AI and the other 21 articles describing review-type works on this
topic. Although some of these review-type articles used the general term “generative AI”, the
main body and supporting evidence focused on LLMs. Twenty-nine articles had in-depth
discussions on ethical issues, whereas the other 12 articles only briefly touched on some
ethical aspects.
Among the 41 articles, 29 articles focused on discussing ethical issues caused by LLMs (and
specifically by GPT in 16 of the articles), covering a wide range of application scenarios and
considered the application of all 10 ethical principles identified in the review (see Figure 1),
as well as other less discussed concerns such as human-AI interaction, and the rights of
LLMs to be considered as co-authors in scientific papers. One paper only commented briefly
on the need for ethical considerations in LLMs and is summarised in the “Others” category.
Although all ethical principles are equally important, some are discussed more often than
others, e.g., non-maleficence (also referred to in the literature as ‘benevolence’), equity, and
privacy.
Fifteen of the 41 articles aimed to resolve some existing ethical issues (for example,
confidentiality of medical data) by using LLMs and other generative AI (e.g., GAN,
autoencoder or diffusion), such as, to reduce privacy concerns by generating synthetic
medical text, to reduce disparity by providing accessible services and assistance, to detect
health-related misinformation, to generate trusted content, and to improve accountability or
transparency over existing approaches. While most articles focused on either identifying
ethical issues caused by generative AI or proposing generative AI-based solutions, three
articles discussed both to provide a more balanced perspective.

Generative AI for image and structured data-based healthcare
Unlike the diverse application scenarios of generative AI based on text data, for image and
structured data, this use of generative AI focuses on data synthesis and encryption. Hence the
majority of articles discussed the methodological developments of generative AI as giving
rise to a more distinctive and focused set of ethical issues.
5
Notably, of the 98 articles on image data and 58 articles on structured data, more than half
(n=63 for image data and n=33 for structured data) only mentioned ethical considerations as a
brief motivation for methodological developments or as a general discussion point. The rest
included more in-depth discussions or evaluations of ethical issues. Among these 155 articles
(as one article covered multiple modalities), 11 articles were review-type work, where 10
articles reviewed methods that mentioned one or two ethical perspectives, and only one
article24 discussed detailed ethical concerns on generative AI applications.
Resolving privacy issues was the main aim of articles for these two data modalities (n=74 for
image data and n=50 for structured data; see Figure 1), predominantly by generating synthetic
data using GAN. Eight articles on image data and 9 articles on structured data used
generative AI to reduce bias, e.g., by synthesizing data for under-represented subgroups in
existing databases. For both data modalities, we did not see explicit discussions on resolving
autonomy, integrity, or morality issues using generative AI, and for structured data the articles
additionally lacked discussions on trust or transparency.
Only 11 articles for image data selectively discussed some ethical issues that generative AI
can give rise to, without specific discussions regarding autonomy, integrity, or morality. For
structured data, only 4 articles discussed equity, privacy, or data security issues caused by
generative AI. Only two articles on structured data included both the cause and resolving
perspectives by discussing ethical issues that may arise from limitations of methods
proposed, specifically bias induced when synthesizing data in order to resolve privacy issues.
"""

# %%
from langchain_core.prompts import ChatPromptTemplate
from langchain_openai import ChatOpenAI

# %%
SYS_PROMPT = """
Act as a Artificial Intelligence Expert.
Transform the input research paper abstract given below
based on the instruction input by the user.
"""
prompt = ChatPromptTemplate.from_messages(
    [
        ("system", SYS_PROMPT),
        ("human", "{instruction}"),
    ]
)

# %%
chatgpt = ChatOpenAI(model_name = 'gpt-4o',temperature=0.0)

# %%
chain = (
    prompt
    |
    chatgpt
)

# %%
from langchain_core.messages import HumanMessage

prompt_txt = f"""
Based on the following research paper abstract,
create the summary report of maximum 10 lines
for a general audience

Abstract:
{paper_abstract}
"""
messages = [HumanMessage(content=prompt_txt)]
user_instruction = {'instruction': messages}

response = chain.invoke(user_instruction)
messages.append(response)

# %% [markdown]
# Here we add the previous LLM response and the new instructions to the list of messages and send the whole thing to the LLM so it has access to the historical conversation

# %%
prompt_txt = f"""
Use only the research paper abstract from earlier and create a detailed report for a healthcare company.
In the report, also include bullet points (3 max) for pros and cons of ethics in Generative AI
"""
messages.append(HumanMessage(content=prompt_txt))
user_instruction = {'instruction': messages}
response = chain.invoke(user_instruction)
messages.append(response)

# %% [markdown]
# Here we add the previous LLM response and the new instructions to the list of messages and send the whole thing to the LLM so it has access to the historical conversation

# %%
prompt_txt = f"""
Use only the research paper abstract from earlier and create a detailed report for a generative AI company solving healthcare problems.
In the report also include sections for key points mentioned around Generative AI for text, images and structured data based healthcare
"""
messages.append(HumanMessage(content=prompt_txt))
user_instruction = {'instruction': messages}
response = chain.invoke(user_instruction)

# %%
print(response.content)
# Out:
# ### Detailed Report on Ethical Issues in Generative AI for Healthcare
#
# #### Introduction
# The rapid adoption of generative AI technologies, such as ChatGPT, in healthcare has brought to light numerous ethical concerns. This report delves into these issues, based on a systematic scoping review of existing research, and proposes a comprehensive ethics checklist to enhance transparency and trust in generative AI applications.
#
# #### Key Findings
#
# 1. **Current Ethical Discussions in Healthcare**
#    - A systematic review was conducted, analyzing 193 articles from January 2013 to July 2023.
#    - The review focused on ethical issues related to generative AI in healthcare, covering text, image, and structured data modalities.
#
# #### Generative AI for Text Data-Based Healthcare
#    - **Scope**: 41 articles discussed ethical considerations for text data, particularly large language models (LLMs) like GPT.
#    - **Key Ethical Issues**:
#      - **Non-maleficence**: Ensuring AI does not cause harm.
#      - **Equity**: Fair access and treatment across different demographics.
#      - **Privacy**: Protecting patient confidentiality.
#    - **Proposed Solutions**: Some articles suggested using generative AI to generate synthetic medical text to mitigate privacy concerns and improve accessibility.
#    - **Additional Concerns**: Human-AI interaction and the rights of LLMs to be considered as co-authors in scientific papers.
#
# #### Generative AI for Image and Structured Data-Based Healthcare
#    - **Scope**: 98 articles on image data and 58 on structured data.
#    - **Key Ethical Issues**:
#      - **Privacy**: Predominantly addressed through data synthesis using GANs.
#      - **Bias Reduction**: Generating data for under-represented subgroups to reduce disparities.
#    - **Gaps**: Limited discussions on broader ethical principles like autonomy, integrity, and trust.
#    - **Proposed Solutions**: Using generative AI to reduce bias and enhance data security.
#
# #### Proposed Ethics Checklist
#    - The review proposes an ethics checklist for comprehensive assessment and transparent documentation of ethical discussions in generative AI development.
#    - This checklist can be integrated into peer review and publication systems to enhance the ethical scrutiny of generative AI research.
#
# #### Pros and Cons of Ethics in Generative AI
#
# **Pros:**
# - **Enhanced Trust**: Transparent ethical practices can build user trust in AI applications.
# - **Improved Accountability**: Clear ethical guidelines ensure developers are accountable for their AI systems.
# - **Risk Mitigation**: Addressing ethical issues proactively can prevent potential harm and legal repercussions.
#
# **Cons:**
# - **Implementation Complexity**: Integrating ethical guidelines into existing systems can be challenging and resource-intensive.
# - **Slower Innovation**: Rigorous ethical scrutiny may slow down the pace of AI development and deployment.
# - **Ambiguity in Guidelines**: Ongoing development of ethical guidelines can lead to uncertainty and inconsistent application.
#
# #### Conclusion
# The integration of generative AI in healthcare necessitates a robust ethical framework to address potential issues. The proposed ethics checklist offers a practical solution to enhance transparency and trust, ensuring responsible use of AI technologies in healthcare. Ongoing ethical scrutiny and practical solutions are essential to navigate the complexities of generative AI and safeguard patient welfare.
